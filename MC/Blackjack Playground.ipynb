# %%
import numpy as np
import sys
if "../" not in sys.path:
  sys.path.append("../") 
from lib.envs.blackjack import BlackjackEnv

# %%
env = BlackjackEnv()

# %%
def print_observation(observation):
    score, dealer_score, usable_ace = observation
    print("Player Score: {} (Usable Ace: {}), Dealer Score: {}".format(
          score, usable_ace, dealer_score))
def strategy(observation):
    score, dealer_score, usable_ace = observation
    # Stick (action 0) if the score is > 20, hit (action 1) otherwise
    return 0 if score >= 20 else 1

for i_episode in range(20):
    observation = env.reset()
    for t in range(100):
        # print_observation(observation)
        print("observation: {} at {}".format(observation, t))
        action = strategy(observation)
        print(action)
        print("Taking action: {}".format( ["Stick", "Hit"][action]))
        observation, reward, done, _ = env.step(action)
        print("observation: {} at {}".format(observation, t))
        if done:
            print_observation(observation)
            print("Game end. Reward: {}\n".format(float(reward)))
            break
# Out:
# observation: (17, 5, False) at 0
# 1
# Taking action: Hit
# observation: (27, 5, False) at 0
# Player Score: 27 (Usable Ace: False), Dealer Score: 5
# Game end. Reward: -1.0
#
# observation: (20, 6, False) at 0
# 0
# Taking action: Stick
# observation: (20, 6, False) at 0
# Player Score: 20 (Usable Ace: False), Dealer Score: 6
# Game end. Reward: 0.0
#
# observation: (20, 9, False) at 0
# 0
# Taking action: Stick
# observation: (20, 9, False) at 0
# Player Score: 20 (Usable Ace: False), Dealer Score: 9
# Game end. Reward: 1.0
#
# observation: (16, 8, False) at 0
# 1
# Taking action: Hit
# observation: (17, 8, False) at 0
# observation: (17, 8, False) at 1
# 1
# Taking action: Hit
# observation: (20, 8, False) at 1
# observation: (20, 8, False) at 2
# 0
# Taking action: Stick
# observation: (20, 8, False) at 2
# Player Score: 20 (Usable Ace: False), Dealer Score: 8
# Game end. Reward: 1.0
#
# observation: (12, 10, False) at 0
# 1
# Taking action: Hit
# observation: (17, 10, False) at 0
# observation: (17, 10, False) at 1
# 1
# Taking action: Hit
# observation: (25, 10, False) at 1
# Player Score: 25 (Usable Ace: False), Dealer Score: 10
# Game end. Reward: -1.0
#
# observation: (13, 2, True) at 0
# 1
# Taking action: Hit
# observation: (21, 2, True) at 0
# observation: (21, 2, True) at 1
# 0
# Taking action: Stick
# observation: (21, 2, True) at 1
# Player Score: 21 (Usable Ace: True), Dealer Score: 2
# Game end. Reward: 1.0
#
# observation: (12, 10, False) at 0
# 1
# Taking action: Hit
# observation: (22, 10, False) at 0
# Player Score: 22 (Usable Ace: False), Dealer Score: 10
# Game end. Reward: -1.0
#
# observation: (14, 10, False) at 0
# 1
# Taking action: Hit
# observation: (23, 10, False) at 0
# Player Score: 23 (Usable Ace: False), Dealer Score: 10
# Game end. Reward: -1.0
#
# observation: (19, 4, False) at 0
# 1
# Taking action: Hit
# observation: (29, 4, False) at 0
# Player Score: 29 (Usable Ace: False), Dealer Score: 4
# Game end. Reward: -1.0
#
# observation: (14, 1, False) at 0
# 1
# Taking action: Hit
# observation: (24, 1, False) at 0
# Player Score: 24 (Usable Ace: False), Dealer Score: 1
# Game end. Reward: -1.0
#
# observation: (12, 7, False) at 0
# 1
# Taking action: Hit
# observation: (14, 7, False) at 0
# observation: (14, 7, False) at 1
# 1
# Taking action: Hit
# observation: (16, 7, False) at 1
# observation: (16, 7, False) at 2
# 1
# Taking action: Hit
# observation: (26, 7, False) at 2
# Player Score: 26 (Usable Ace: False), Dealer Score: 7
# Game end. Reward: -1.0
#
# observation: (16, 9, False) at 0
# 1
# Taking action: Hit
# observation: (26, 9, False) at 0
# Player Score: 26 (Usable Ace: False), Dealer Score: 9
# Game end. Reward: -1.0
#
# observation: (13, 10, False) at 0
# 1
# Taking action: Hit
# observation: (23, 10, False) at 0
# Player Score: 23 (Usable Ace: False), Dealer Score: 10
# Game end. Reward: -1.0
#
# observation: (17, 10, True) at 0
# 1
# Taking action: Hit
# observation: (18, 10, True) at 0
# observation: (18, 10, True) at 1
# 1
# Taking action: Hit
# observation: (18, 10, False) at 1
# observation: (18, 10, False) at 2
# 1
# Taking action: Hit
# observation: (19, 10, False) at 2
# observation: (19, 10, False) at 3
# 1
# Taking action: Hit
# observation: (20, 10, False) at 3
# observation: (20, 10, False) at 4
# 0
# Taking action: Stick
# observation: (20, 10, False) at 4
# Player Score: 20 (Usable Ace: False), Dealer Score: 10
# Game end. Reward: 0.0
#
# observation: (15, 10, True) at 0
# 1
# Taking action: Hit
# observation: (13, 10, False) at 0
# observation: (13, 10, False) at 1
# 1
# Taking action: Hit
# observation: (23, 10, False) at 1
# Player Score: 23 (Usable Ace: False), Dealer Score: 10
# Game end. Reward: -1.0
#
# observation: (15, 2, False) at 0
# 1
# Taking action: Hit
# observation: (18, 2, False) at 0
# observation: (18, 2, False) at 1
# 1
# Taking action: Hit
# observation: (23, 2, False) at 1
# Player Score: 23 (Usable Ace: False), Dealer Score: 2
# Game end. Reward: -1.0
#
# observation: (18, 10, True) at 0
# 1
# Taking action: Hit
# observation: (18, 10, False) at 0
# observation: (18, 10, False) at 1
# 1
# Taking action: Hit
# observation: (28, 10, False) at 1
# Player Score: 28 (Usable Ace: False), Dealer Score: 10
# Game end. Reward: -1.0
#
# observation: (21, 2, False) at 0
# 0
# Taking action: Stick
# observation: (21, 2, False) at 0
# Player Score: 21 (Usable Ace: False), Dealer Score: 2
# Game end. Reward: 1.0
#
# observation: (13, 8, False) at 0
# 1
# Taking action: Hit
# observation: (19, 8, False) at 0
# observation: (19, 8, False) at 1
# 1
# Taking action: Hit
# observation: (29, 8, False) at 1
# Player Score: 29 (Usable Ace: False), Dealer Score: 8
# Game end. Reward: -1.0
#
# observation: (18, 6, False) at 0
# 1
# Taking action: Hit
# observation: (28, 6, False) at 0
# Player Score: 28 (Usable Ace: False), Dealer Score: 6
# Game end. Reward: -1.0
